# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from downloader import download_streetview, reverse_geocode, refine_location
from data import sample_voters_with_precincts
from data import load_data, get_precincts
from renderer import *

from PIL import Image

import io

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import geopandas as gpd

# %%
data = load_data(10)

# %%
data
# Out:
#            R     D    O state  \
# 35182   2153  1321   34    FL
# 40004   1971   922   60    GA
# 6858     393  1635   33    CA
# 109680  2071   420   33    NC
# 90397   6228  4858  211    NJ
# 108612  2256   914   31    NC
# 16752   1471  1300   54    CA
# 133109   485   217    8    SC
# 94232    330   659   27    NY
# 79879   1001  1080   55    MN
#
#                                                  geometry selected_party  \
# 35182   POLYGON ((-80.43017399999999 27.646014, -80.43...              D
# 40004   POLYGON ((-84.560362 34.130462, -84.560063 34....              R
# 6858    POLYGON ((-122.1066081971455 37.68976202750137...              D
# 109680  POLYGON ((-80.08022799999998 35.80957999999968...              R
# 90397   POLYGON ((-74.79505368290255 40.51492794976577...              D
# 108612  POLYGON ((-81.034587 35.46048199999967, -81.03...              R
# 16752   POLYGON ((-121.3369092282521 38.7247620739986,...              D
# 133109  POLYGON ((-81.50252855720233 33.46564626220876...              R
# 94232   POLYGON ((-78.84976399999999 42.96993999999999...              D
# 79879   POLYGON ((-93.30923116306253 45.19008287649358...              R
#
#                  x          y          ox         oy
# 35182   -80.472623  27.616929  -80.454520  27.630773
# 40004   -84.581407  34.114010  -84.571751  34.121907
# 6858   -122.117594  37.694603 -122.114818  37.689119
# 109680  -80.077456  35.858276  -80.071814  35.839559
# 90397   -74.799825  40.620118  -74.779584  40.582180
# 108612  -81.021811  35.464109  -80.994878  35.473084
# 16752  -121.341476  38.743591 -121.338192  38.738682
# 133109  -81.563270  33.486680  -81.562547  33.454611
# 94232   -78.849783  42.966739  -78.850238  42.964806
# 79879   -93.319593  45.206534  -93.314177  45.202909

# %%
from PIL import Image

# %%
# Out:
# 0.98958740234375
